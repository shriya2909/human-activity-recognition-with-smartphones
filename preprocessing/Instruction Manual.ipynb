# %%
import preprocess
import numpy as np
import pandas as pd

# %%
proc = preprocess.SequenceHandler('../data/train.csv', size=26) # size = number of time steps of activity sequence (mean = 26)
# Out:
# Extracting sequences ...
# Adjusting sequence length to 26 ...
# Sequence data acquired. (Now convert to appropiate dimension)

# %% [markdown]
# # 1-Dimensional Sequence Data

# %% [markdown]
# This is what you'll be using the most.

# %%
proc.convert_sequence_to_1D_sample()
# Out:
# Generating 1D view of sequence data ...
# Sequence samples generated - 280 sequences rows,  14586 feature columns + 2 helper columns + 1 class column.
# (Now sequence 1-dim is accessible)

# %%
df = proc.get_sequence(1)
df
# Out:
#     tBodyAcc-mean()-X lag(tBodyAcc-mean()-X, 1) lag(tBodyAcc-mean()-X, 2)  \
# 0            0.288585                  0.278419                  0.279653
# 1            0.144504                  0.287252                  0.279998
# 2            0.403474                  0.278373                  0.276555
# 3            0.282022                  0.255841                  0.254867
# 4            0.358455                  0.301715                  0.281552
# 5            0.183604                  0.279183                  0.301162
# 6            0.260762                  0.289817                  0.284511
# 7            0.262976                  0.298118                  0.277275
# 8            0.393654                  0.319324                  0.279037
# 9            0.310763                  0.264539                  0.269635
# 10         -0.0662389                -0.0832871                  0.259115
# 11           0.250126                  0.273243                  0.346254
# ...

# %%
# Eg: 1st row of above output = flattened version of below output (2-Dimensional activity sequence of subject-1)
proc.get_sequence(-1)["1"] # shows the uncleaned, 2 dimensional activity sequence of subject-1
# Out:
#     tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0            0.288585          -0.020294          -0.132905         -0.995279
# 1            0.278419          -0.016411          -0.123520         -0.998245
# 2            0.279653          -0.019467          -0.113462         -0.995380
# 3            0.279174          -0.026201          -0.123283         -0.996091
# 4            0.276629          -0.016570          -0.115362         -0.998139
# 5            0.277199          -0.010098          -0.105137         -0.997335
# 6            0.279454          -0.019641          -0.110022         -0.996921
# 7            0.277432          -0.030488          -0.125360         -0.996559
# 8            0.277293          -0.021751          -0.120751         -0.997328
# 9            0.280586          -0.009960          -0.106065         -0.994803
# 10           0.276880          -0.012722          -0.103438         -0.994815
# ...

# %% [markdown]
# # 2-Dimensional Sequence Data

# %% [markdown]
# This is mainly for neural networks. You can try and use this for other algorithms, if possible.

# %%
proc.convert_sequence_to_2D_sample()
# Out:
# Generating 2D view of sequence data ...
# Sequence samples generated - design matrix (#samples, #time_steps, #features) = (280, 26, 561), class vector (#samples) = (280). (Now sequence 2-dim is accessible)

# %%
design_matrix, class_labels = proc.get_sequence(2)
print(design_matrix.shape) # Dimensions of design matrix
print(design_matrix)
# Out:
# (280, 26, 561)
# [[[ 0.28858451 -0.02029417 -0.13290514 ... -0.84124676  0.17994061
#    -0.05862692]
#   [ 0.27841883 -0.01641057 -0.12352019 ... -0.8447876   0.18028889
#    -0.05431672]
#   [ 0.27965306 -0.01946716 -0.11346169 ... -0.84893347  0.18063731
#    -0.04911782]
#   ...
#   [ 0.2792002  -0.01771443 -0.10916135 ... -0.75896013  0.26425623
#     0.03045603]
#   [ 0.28171549 -0.01191068 -0.10287513 ... -0.75897692  0.26422361
#     0.03074315]
#   [ 0.27899267 -0.01453103 -0.10659617 ... -0.76219671  0.26209013
#     0.02940367]]
#
#  [[ 0.14450396  0.18926326  0.06276932 ... -0.66708465  0.05421616
#    -0.21887457]
#   [ 0.28725164 -0.03745506 -0.14597431 ... -0.56480737 -0.0270448
#    -0.26605456]
#   [ 0.2799976  -0.01948404 -0.10572355 ... -0.57936742 -0.02156689
#    -0.2575301 ]
#   ...
#   [ 0.2790872  -0.01908324 -0.10588882 ... -0.64545984 -0.01704724
#    -0.20796204]
#   [ 0.30854438 -0.0454532  -0.12843249 ... -0.66207889 -0.01732198
#    -0.19531374]
# ...

# %%
print(len(class_labels)) # Length of class vector
print(class_labels)
# Out:
# 280
# ...
